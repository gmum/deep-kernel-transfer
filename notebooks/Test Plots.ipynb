# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # NN results

# %%
PATH='/home/anowak/projects/deep-kernel-transfer/save/regression_sines_nn2/checkpoints/sines/MLP2_DKT_test_results.npy'

# %%
data = np.load(PATH, allow_pickle=True).item()

# %%
data.keys()
# Out:
# dict_keys(['mse_list', 'nll_list', 'mean', 'lower', 'upper', 'x', 'y', 'mse', 'mse_std', 'nll', 'nll_std'])

# %%
idx = np.argsort(data["x"][0],axis=0).reshape(-1)

# %%
def plot_for_n_single(data,n=0):
    idx = np.argsort(data["x"][n],axis=0).reshape(-1)
    fig, ax = plt.subplots(1,1, figsize=(8,3*2))
    ax.plot(data["x"][n][idx], data["y"][n][idx], linestyle="--", color="green")
    ax.plot(data["x"][n][idx], data["y"][n][idx], linestyle='', marker='o', color="green")
    ax.plot(data["x"][n][idx], data["mean"][n][idx])
    ax.fill_between(data["x"][n][idx].reshape(-1), data["lower"][n][idx], data["upper"][n][idx], alpha=0.2)

    ax.set_ylim((-4,4))
    plt.show()


def plot_for_n(data,n=0):
    idx = np.argsort(data["x"][n],axis=0).reshape(-1)
    fig, (ax, ax2) = plt.subplots(1,2, figsize=(8*2,3*2))
    ax.plot(data["x"][n][idx], data["y"][n][idx, 0], linestyle="--", color="green")
    ax.plot(data["x"][n][idx], data["y"][n][idx, 0], linestyle='', marker='o', color="green")
    ax.plot(data["x"][n][idx], data["mean"][n][idx, 0])
    ax.fill_between(data["x"][n][idx].reshape(-1), data["lower"][n][idx, 0], data["upper"][n][idx, 0], alpha=0.2)

    ax2.plot(data["x"][n][idx], data["y"][n][idx, 1], linestyle="--", color="green")
    ax2.plot(data["x"][n][idx], data["y"][n][idx, 1], linestyle='', marker='o', color="green")
    ax2.plot(data["x"][n][idx], data["mean"][n][idx, 1])
    ax2.fill_between(data["x"][n][idx].reshape(-1), data["lower"][n][idx, 1], data["upper"][n][idx, 1], alpha=0.2)
    plt.show()

# %%
plot_for_n_single(data, 1)

# %%
plot_for_n_single(data, 0)

# %%
plot_for_n_single(data, 4)

# %%
plot_for_n(data, 1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-6d852b0d8ea4> in <module>
# ----> 1 plot_for_n(data, 1)
#
# <ipython-input-6-198c70e1b3de> in plot_for_n(data, n)
#      14     idx = np.argsort(data["x"][n],axis=0).reshape(-1)
#      15     fig, (ax, ax2) = plt.subplots(1,2, figsize=(8*2,3*2))
# ---> 16     ax.plot(data["x"][n][idx], data["y"][n][idx, 0], linestyle="--", color="green")
#      17     ax.plot(data["x"][n][idx], data["y"][n][idx, 0], linestyle='', marker='o', color="green")
#      18     ax.plot(data["x"][n][idx], data["mean"][n][idx, 0])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
plot_for_n(data, 0)

# %%
plot_for_n(data, 2)

# %% [markdown]
# # rbf + indices kernel results

# %%
PATH='/home/anowak/projects/deep-kernel-transfer/save/multi_regression_right_sines_rbf/checkpoints/sines/MLP2_DKT_test_results.npy'

# %%
data = np.load(PATH, allow_pickle=True).item()

# %%
idx = np.argsort(data["x"][0],axis=0).reshape(-1)

# %%
plot_for_n(data, 1)

# %%
plot_for_n(data, 0)
